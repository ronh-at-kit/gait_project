# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim

import numpy as np
import time
import os
import os.path as path
import copy

# from gait_analysis import AnnotationsCasia as Annotations
# from gait_analysis import CasiaDataset
# from gait_analysis.Config import Config
# from gait_analysis import Composer
# from gait_analysis import WeightWatcher
from gait_analysis import AccuracyTrackerTrainTest

import matplotlib.pyplot as plt

# from gait_analysis.Models import PretrainConvFlow
# from gait_analysis.Models.TransferConvLSTMFlow import TransferConvLSTMFlow

print("done")
# %matplotlib inline
# Out:
# done

# %%
tt_acc_tracker = AccuracyTrackerTrainTest([0,1,2])

# %%
data1=tt_acc_tracker.read_from_csv('/home/ron/PycharmProjects/Gait2019/plots/B1/')
data16=tt_acc_tracker.read_from_csv('/home/ron/PycharmProjects/Gait2019/plots/B16/')
data32=tt_acc_tracker.read_from_csv('/home/ron/PycharmProjects/Gait2019/plots/B32/')

# %%
plt.plot(data1['test']['acc_tot'])
plt.plot(data16['test']['acc_tot'])
plt.plot(data32['test']['acc_tot'])
plt.legend({'B1','B16','B32'})
plt.title('accuracy total')
# Out:
# Text(0.5, 1.0, 'accuracy total')

# %%
plt.plot(np.linspace(0,200,len(data1['test']['loss'])), data1['test']['loss'])
plt.plot(np.linspace(0,200,len(data16['test']['loss'])), data16['test']['loss'])
plt.plot(np.linspace(0,200,len(data32['test']['loss'])), data32['test']['loss'])
plt.legend({'B1','B16','B32'})
plt.title('accuracy total')
# Out:
# Text(0.5, 1.0, 'accuracy total')

# %%
plt.plot(data1['test']['acc0'])
plt.plot(data16['test']['acc0'])
plt.plot(data32['test']['acc0'])
plt.legend({'B1','B16','B32'})
plt.title('accuracy label 0')
# Out:
# Text(0.5, 1.0, 'accuracy label 0')

# %%
plt.plot(data1['test']['acc1'])
plt.plot(data16['test']['acc1'])
plt.plot(data32['test']['acc1'])
plt.legend({'B1','B16','B32'})
plt.title('accuracy label 1')
# Out:
# Text(0.5, 1.0, 'accuracy label 1')

# %%
plt.plot(data1['test']['acc2'])
plt.plot(data16['test']['acc2'])
plt.plot(data32['test']['acc2'])
plt.legend({'B1','B16','B32'})
plt.title('accuracy label 0')
# Out:
# Text(0.5, 1.0, 'accuracy label 0')
