# %%
from gait_analysis import CasiaDataset, settings
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/ron/anaconda3/envs/gait_37/lib/python3.7/site-packages/lml/loader.py:64: UserWarning: Deprecated! since version 0.0.3. Please use scan_plugins_regex!
#   "Deprecated! since version 0.0.3. Please use scan_plugins_regex!"

# %% [markdown]
# ## Loading the dataset

# %%
datasets = CasiaDataset()
item = datasets[1]
annotations = item['annotations']
scenes = item['scenes']
# Out:
# loading configuration  default

# %%
datasets.dataset_items[1]
# Out:
# (1, 'bg-02')

# %% [markdown]
# ## Verification
# This data set correspond to the **person 001**, **subsequence bg-02** and **angle 90** because the default configuration is 90 degrees for grouping **'person_sequence'**

# %%
annotations.head(10)
# Out:
#     frame_id   left_foot  right_foot
# 40        40  IN_THE_AIR   ON_GROUND
# 41        41  IN_THE_AIR   ON_GROUND
# 42        42  IN_THE_AIR   ON_GROUND
# 43        43  IN_THE_AIR   ON_GROUND
# 44        44  IN_THE_AIR   ON_GROUND
# 45        45   ON_GROUND   ON_GROUND
# 46        46   ON_GROUND   ON_GROUND
# 47        47   ON_GROUND   ON_GROUND
# 48        48   ON_GROUND  IN_THE_AIR
# 49        49   ON_GROUND  IN_THE_AIR

# %% [markdown]
# We verify the transition are correct for the right foot at 44 to 45 and for the left foot at 47 to 48

# %%
plt.figure(figsize=(30,40))
print('left foot trans from air to ground')
plt.subplot(131)
plt.imshow(scenes[4])
plt.title('frame 44')
plt.subplot(132)
plt.imshow(scenes[5])
plt.title('frame 45')
plt.subplot(133)
plt.imshow(scenes[6])
plt.title('frame 46')
plt.show()

plt.figure(figsize=(30,40))
print('right foot trans from Ground to air')
plt.subplot(131)
plt.imshow(scenes[7])
plt.title('frame 47')
plt.subplot(132)
plt.imshow(scenes[8])
plt.title('frame 48')
plt.subplot(133)
plt.imshow(scenes[9])
plt.title('frame 49')
plt.show()
# Out:
# left foot trans from air to ground
# right foot trans from Ground to air

# %% [markdown]
# Comment out bellow to get a view of the whole dataframe

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
     display(annotations)
# Out:
#      frame_id   left_foot  right_foot
# 40         40  IN_THE_AIR   ON_GROUND
# 41         41  IN_THE_AIR   ON_GROUND
# 42         42  IN_THE_AIR   ON_GROUND
# 43         43  IN_THE_AIR   ON_GROUND
# 44         44  IN_THE_AIR   ON_GROUND
# 45         45   ON_GROUND   ON_GROUND
# 46         46   ON_GROUND   ON_GROUND
# 47         47   ON_GROUND   ON_GROUND
# 48         48   ON_GROUND  IN_THE_AIR
# 49         49   ON_GROUND  IN_THE_AIR
# 50         50   ON_GROUND  IN_THE_AIR
# 51         51   ON_GROUND  IN_THE_AIR
# 52         52   ON_GROUND  IN_THE_AIR
# 53         53   ON_GROUND  IN_THE_AIR
# 54         54   ON_GROUND  IN_THE_AIR
# 55         55   ON_GROUND  IN_THE_AIR
# 56         56   ON_GROUND   ON_GROUND
# 57         57   ON_GROUND   ON_GROUND
# 58         58   ON_GROUND   ON_GROUND
# 59         59   ON_GROUND   ON_GROUND
# 60         60  IN_THE_AIR   ON_GROUND
# 61         61  IN_THE_AIR   ON_GROUND
# 62         62  IN_THE_AIR   ON_GROUND
# 63         63  IN_THE_AIR   ON_GROUND
# ...

# %% [markdown]
# ## Changing the configuration on fly

# %% [markdown]
# We can change the quickly the indexing to access all the angles

# %%
from gait_analysis.Config import Config
c = Config()
c.config['indexing']['grouping'] = 'person_sequence_angle'
dataset_2 = CasiaDataset()
item = dataset_2[1]
annotations = item['annotations']
scenes = item['scenes']

# %%
dataset_2.dataset_items[1]
# Out:
# (1, 'bg-01', 54)

# %%
annotations.head(1)
annotations.tail(1)
# Out:
#     frame_id   left_foot right_foot
# 81        81  IN_THE_AIR  ON_GROUND

# %%
plt.figure(figsize=(30,40))
print('left foot trans from air to ground')
plt.subplot(131)
plt.imshow(scenes[5])
plt.title('frame 35')
plt.subplot(132)
plt.imshow(scenes[6])
plt.title('frame 36')
plt.subplot(133)
plt.imshow(scenes[7])
plt.title('frame 37')
plt.show()

plt.figure(figsize=(30,40))
print('right foot trans from Ground to air')
plt.subplot(131)
plt.imshow(scenes[8])
plt.title('frame 38')
plt.subplot(132)
plt.imshow(scenes[10])
plt.title('frame 39')
plt.subplot(133)
plt.imshow(scenes[11])
plt.title('frame 40')
plt.show()
# Out:
# left foot trans from air to ground
# right foot trans from Ground to air

# %% [markdown]
# We can change the loaded object configuration

# %%
c.config
# Out:
# {'indexing': {'selection': 'manual_people',
#   'people_selection': [1],
#   'sequences_selection': ['bg-01', 'cl-01'],
#   'grouping': 'person_sequence_angle'},
#  'pose': {'load': False,
#   'preprocess': True,
#   'D': 2,
#   'body_keypoints_include_list': ['LAnkle',
#    'RAnkle',
#    'LKnee',
#    'RKnee',
#    'RHip',
#    'LHip']},
#  'flow': {'load': False,
#   'preprocess': True,
#   'method': 'dense',
#   'load_patches': True,
#   'patch_size': 5},
#  'scenes': {'load': True,
#   'preprocess': False,
#   'gray_scale': False,
#   'load_tracked': False,
#   'sequences': ['bg', 'cl', 'nm'],
#   'angles': [90]}}

# %%
from gait_analysis.Config import Config
c = Config()
c.config['indexing']['grouping'] = 'person_sequence_angle'
c.config['pose']['load'] = True
c.config['flow']['load'] = True

# %%
dataset_3 = CasiaDataset()
item = dataset_3[1]
annotations = item['annotations']
scenes = item['scenes']
poses = item['poses']
valid_poses = item['valid_indices']
flows = item['flows']

print(valid_poses)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True False False
#  False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
dataset_3.dataset_items[1]
# Out:
# (1, 'bg-01', 54)

# %%
plt.figure(figsize=(30,40))
print('left foot trans from air to ground')
plt.subplot(131)
plt.imshow(flows[5][:,:,2])
plt.title('flows 35')
plt.subplot(132)
plt.imshow(flows[6][:,:,2])
plt.title('flows 36')
plt.subplot(133)
plt.imshow(flows[7][:,:,2])
plt.title('flows 37')
plt.show()

plt.figure(figsize=(30,40))
print('right foot trans from Ground to air')
plt.subplot(131)
plt.imshow(flows[9][:,:,2])
plt.title('flows 38')
plt.subplot(132)
plt.imshow(flows[10][:,:,2])
plt.title('frame 39')
plt.subplot(133)
plt.imshow(flows[11][:,:,2])
plt.title('frame 40')
plt.show()
# Out:
# left foot trans from air to ground
# right foot trans from Ground to air

# %%
print(poses.shape)
print(poses[:,:,20])
# Out:
# (6, 2, 52)
# [[376.38  211.9  ]
#  [368.585 262.85 ]
#  [360.802 319.003]
#  [398.575 211.926]
#  [405.105 261.536]
#  [433.869 298.06 ]]

# %%
print(np.shape(flows[0][:,:,2]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1e02d4c1a34c> in <module>
# ----> 1 print(np.shape(flows[0][:,:,2]))
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
#print(poses)
poses2 = np.array(list(poses))
#print(poses2)
test = np.array(list(poses[0]))
print(test)
#print(poses2)
poses3 = np.zeros((6,2,52))
test2 =[np.array(list(poses[i])) for i in range(51)]
test3 = np.array(test2)
test3 = np.transpose(test3,(1,2,0))


print(test3.shape)

# %% [markdown]
# #Verification poses

# %%
#pose verification #done
dataset = CasiaDataset()
NR_DS = 6

item = dataset[NR_DS] #prints output here

annotations = item['annotations']
scenes = item['scenes']
#print(dataset.dataset_items[NR_IM])
poses = item['poses']
print(poses.shape)
print(poses[:,:,0])

print(annotations.head(1))
#print("Current item in dataset:")
#print(item)
#print("Current dataset:")
#print(dataset.dataset_items[0])

#print(np.array(list(poses)))

#plt.figure(figsize=(9,12))

#for i in range(len(dataset)):
    #find maximal extension of pixels
    


"""
print('Test image:')
plt.hold(True)
for i in range(5):
    plt.imshow(scenes[i])
    plt.plot(poses[:,0,i],poses[:,1,i],'xy')
    #plt.hold(True)
    title = 'Scene' + str(i)
    plt.title(title)
    plt.show()
"""
# Out:
# (6, 2, 62)
# [[493.86  192.354]
#  [495.135 236.728]
#  [502.981 283.723]
#  [512.123 192.364]
#  [502.999 235.458]
#  [510.809 285.05 ]]
#     frame_id   left_foot right_foot
# 34        34  IN_THE_AIR  ON_GROUND
# Test image:

# %%
#Suspicious Pose

dataset = CasiaDataset()
nr_set = 6
frame = 61#34 from annotations
item = dataset[nr_set]
scenes = item['scenes']
poses = item['poses']
annotations = item['annotations']
valid_poses = item['valid_indices']
print(valid_poses)
print(valid_poses[frame+34])
print(dataset.dataset_items[nr_set])
print("Poses shape:",poses.shape)
print("Suspicious pose: ",poses[:,:,frame])
print(annotations.head(1))
#print(poses[:,:,frame])
plt.imshow(scenes[frame])
plt.plot(poses[:,0,frame],poses[:,1,frame],'oy')
plt.show()
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False False False False False False False False False False False]
# True
# (1, 'bg-02', 54)
# Poses shape: (6, 2, 62)
# Suspicious pose:  [[ 26.5625 247.191 ]
#  [ 14.822  316.369 ]
#  [  0.       0.    ]
#  [ 47.4396 247.168 ]
#  [ 59.238  317.692 ]
#  [ 86.6382 379.    ]]
#     frame_id   left_foot right_foot
# 34        34  IN_THE_AIR  ON_GROUND

# %%
#FIND MAX WINDOW FOR CROP

#disregard flow:
from gait_analysis.Config import Config
import numpy as np
c = Config()
c.config['flow']['load'] = False

dataset = CasiaDataset()
#for i in range(len(dataset)):
x_max = []
y_max = []
x_center = []
y_center = []
for i in range(len(dataset)): 
#for i in range(5):
    item = dataset[i] #generates output
    annotations = item['annotations']
    scenes = item['scenes']
    poses = item['poses']
    #print("Shapes:")
    #print(poses.shape)
    x_tmp = []
    y_tmp = []
    for j in range(poses.shape[2]):
        #cycle through all frames to find largest 

        #detect invalid poses
        if (min(poses[:,0,j]) == 0 and min(poses[:,1,j]) == 0):
            print("Invalid pose detected! Located in: ", dataset.dataset_items[i],"Frame(valid):", j)
            
        else:
            abs_delta_x = max(poses[:,0,j]) - min(poses[:,0,j])
            abs_delta_y = max(poses[:,1,j]) - min(poses[:,1,j])
            #center_x = (max(poses[:,0,j]) + min(poses[:,1,j]))/2
            #center_y = (max(poses[:,1,j]) + min(poses[:,0,j]))/2
            #x_max.append(abs_delta_x)
            #y_max.append(abs_delta_y)
            x_tmp.append(abs_delta_x)
            y_tmp.append(abs_delta_y)
            #x_center.append(center_x)
            #y_center.append(center_y)
    #print("Iteration {}: Max: {}".format(i,[max(x_tmp),max(y_tmp)]))
    x_max.append(max(x_tmp))
    y_max.append(max(y_tmp))

print("Max size for crop:",max(x_max),max(y_max))
print("Mean:",np.mean(x_max),np.mean(y_max))

crop = np.ceil(max(max(x_max,y_max)))
margin = 10
#START CROPPING
for i in range(5):
    item = dataset[i]
    annotations = item['annotations']
    scenes = item['scenes']
    poses = item['poses']

        for j in range(poses.shape[2]):
# Out:
# Invalid pose detected! Located in:  (1, 'bg-02', 54) Frame(valid): 61
# Max size for crop: 121.322 197.054
# Mean: 94.39895 156.35166666666672
# ...

# %%
import matplotlib.pyplot as plt
#crop = np.ceil(197.054)
#margin = 10
print(crop,margin)
for i in range(1):
    item = dataset[i]
    annotations = item['annotations']
    scenes = item['scenes']
    poses = item['poses']

    for j in range(poses.shape[2]):
        if (min(poses[:,0,j]) == 0 and min(poses[:,1,j]) == 0):
            print("Cropping carefully TODO")
        else:
            center_x = (max(poses[:,0,j]) + min(poses[:,0,j])) / 2;
            center_y = (max(poses[:,1,j]) + min(poses[:,1,j])) / 2;
        im = scenes[j]
        im_new = im[center_x-crop/2:center_y+crop/2,center_y-crop/2:center_y+crop/2]
        #TODO make integer
        plt.imshow(im)
        plt.imshow(im_new)
# Out:
# 198.0 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-27b76d5490a9> in <module>
#      16             center_y = (max(poses[:,1,j]) + min(poses[:,1,j])) / 2;
#      17         im = scenes[j]
# ---> 18         im_new = im[center_x-crop/2:center_y+crop/2,center_y-crop/2:center_y+crop/2]
#      19         plt.imshow(im)
#      20         plt.imshow(im_new)
#
# TypeError: slice indices must be integers or None or have an __index__ method
